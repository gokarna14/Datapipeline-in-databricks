# %%
# %run /Users/075bei014.gokarna@pcampus.edu.np/Load_Raw

# %%
# %run /Users/075bei014.gokarna@pcampus.edu.np/Loading_Clean_Data

# %% [markdown]
# # Collect Hourly Data

# %%
import time

def wait(seconds : int = 500):
    time.sleep(seconds)

count = 1
while(True):
    Weather.get_and_load_raw()
    Clean_Data_Load()
    print(f"HOULRY Data Uploaded -> {count}")
    wait(3600)
    count += 1
# Out:
# HOULRY Data Uploaded -> 1
# HOULRY Data Uploaded -> 2
# HOULRY Data Uploaded -> 3
# HOULRY Data Uploaded -> 4
