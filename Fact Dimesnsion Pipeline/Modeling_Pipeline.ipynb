# %%
# %run /Users/075bei014.gokarna@pcampus.edu.np/Dim_Tables_Load
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
# Dimension table 'dim_date' is up to date.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
# Dimension table 'dim_time' has been successfully loaded.
# ...

# %%
# %run /Users/075bei014.gokarna@pcampus.edu.np/Fact_Table_Load
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
import time

def wait(seconds : int = 500):
    time.sleep(seconds)

count = 1
while(True):
    load_hourly()
    print(f"Fact hourly table updated -> {count}")
    load_daily()
    print(f"Fact daily table updated -> {count}")
    wait(3600)
    count += 1
# Out:
# Fact hourly table updated -> 1
# Fact daily table updated -> 1
